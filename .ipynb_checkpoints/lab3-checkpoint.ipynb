# %% [markdown]
# Physics 91SI
#
# Spring 2015
#
# Lab 2
# =====
#
# Part 1
# ------

# %%
# Don't edit this function
def load_sample():
    """Return the entire text of Hamlet in a string."""
    with open('hamlet.txt') as f:
        sample = f.read()
    return sample

# %%
# Edit this function. "pass" tells Python to do nothing.
def parse_sample(sample, words_only=True, sort_list=True):
    wordlist = []
    for line in sample.split():
        for word in line.split():
            wordlist.append(word)
    if words_only==True: #Strips punctuation and capitalization from words in list. Still not working...
        punctuation=["!",";",":","'", ''',''','''.''', '''"''', '''?''']
        for word in wordlist:
            no_punct=''
            for char in word:
                if char not in punctuation: 
                    no_punct=no_punct+char
            word = no_punct
    if sort_list==True: #Sorts the list. Works!
        wordlist.sort() 
    return wordlist

# %% [markdown]
# Part 2
# ------

# %%
def count_freq(lst):
    """Return a dict of word frequencies given a list of words.
    
    Arguments:
    -- lst: a list of strings
    
    Returns:
    -- freq_dict: a dictionary of word: frequency pairs. The keys are strings
       containing the words, and the values are integers indicating how many
       times each word appears.
    
    Example:
    >>> count_freq(['time', 'after', 'time'])
    {'time': 2, 'after': 1}
    """
    pass

def mean(lst):
    """Return the arithmetic mean of a list of numbers."""
    pass

def stdev(lst):
    """Return the standard deviation of a list of numbers."""
    pass

def median(lst):
    """Return the median of a list of numbers."""
    pass

# %% [markdown]
# Part 3
# ------

# %%
def print_stats(lst):
    """Print common statistics about the word frequencies of a list of words."""
    pass

# %%
sample=load_sample()
load_sample()
parse_sample(sample)
# Out:
# ['&',
#  '&',
#  '&',
#  '&',
#  '&',
#  "'",
#  "'A",
#  "'Adam",
#  "'Adieu,",
#  "'And",
#  "'Anon",
#  "'As",
#  "'As'es",
#  "'But",
#  "'Choose",
#  "'Doubt",
#  "'Faith,",
#  "'Faith,",
#  "'Faith,",
#  "'Faith,",
#  "'For,",
#  "'Fore",
#  "'Forgive",
#  "'Gainst",
#  "'Good",
#  "'Good",
#  "'HAMLET.'",
#  "'He",
#  "'High",
#  "'Horatio,",
#  "'I",
#  "'I",
#  "'I",
#  "'If",
#  "'In",
#  "'It",
#  "'Laertes",
#  "'Lord",
#  "'Naked!",
#  "'Now",
#  "'O",
#  "'One",
#  "'One.'",
#  "'Run",
#  "'Sblood,",
#  "'Sblood,",
#  "'Swounds,",
#  "'Swounds,",
#  "'The",
#  "'The",
#  "'The",
#  "'There",
#  "'Thine",
#  "'This",
#  "'This",
#  "'Thou",
#  "'Thus",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'Tis",
#  "'To",
#  "'Twere",
#  "'Twere",
#  "'Twere",
#  "'Twere",
#  "'Twill,",
#  "'We",
#  "'Well,",
#  "'While",
#  "'Who",
#  "'a",
#  "'alone.'",
#  "'beautified'",
#  "'closes",
#  "'closes",
#  "'em?",
#  "'em?",
#  "'faith",
#  "'friend",
#  "'friend,'",
#  "'gainst",
#  "'gainst",
#  "'gainst",
#  "'gainst",
#  "'gentleman,'",
#  "'gentleman.'",
#  "'gins",
#  "'havior",
#  "'ild",
#  "'imponed,'",
#  "'man",
#  "'mobled",
#  "'no'?",
#  "'not",
#  "'s",
#  "'scape",
#  "'scape",
#  "'scapes",
#  "'se",
#  "'seems.'",
#  "'should'",
#  "'t",
#  "'t",
#  "'t",
#  "'t.",
#  "'t.",
#  "'t.",
#  "'t?",
#  "'take",
#  "'the",
#  "'the",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis",
#  "'tis,",
#  "'twas",
#  "'twas",
#  "'twas",
#  "'twas",
#  "'twas",
#  "'tween",
#  "'twere",
#  "'twere",
#  "'twere",
#  "'twere",
#  "'twere,",
#  "'twere,",
#  "'twere,--I",
#  "'twill",
#  "'twill",
#  "'twill",
#  "'twixt",
#  "'twixt",
#  "'twould",
#  "'would'",
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'ACT',
#  'ACT',
#  'ACT',
#  'ACT',
#  'ACT',
#  'About',
#  'About',
#  'About,',
#  'Absent',
#  'Abuses',
#  'According',
#  'Acts',
#  "Adam's",
#  'Addicted',
#  'Adieu,',
#  'Adieu,',
#  'Adieu.',
#  'Admit',
#  "Aeneas'",
#  'Affection!',
#  'Affront',
#  'After',
#  'After',
#  'Against',
#  'Against',
#  'Against',
#  'Against',
#  'Ah,',
#  'Ah,',
#  'Ah,',
#  'Ah,',
#  'Alack,',
#  'Alack,',
#  'Alack,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alas,',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander,',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'Almost',
#  'Am',
#  'Am',
#  'Ambassador',
#  'Ambassadors,',
#  'Among',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And,',
#  'And--would',
#  'Angels',
#  'Anon',
#  'Anon,',
#  'Another',
#  'Another',
#  'Another',
#  'Another',
#  'Another',
#  'Another',
#  'Answer,',
#  'Antiquity',
#  'Appears',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Arm',
#  "Arm'd,",
#  "Arm'd,",
#  'Armed',
#  'Aroused',
#  'Art',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As,',
#  'Aside',
#  'Assume',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attendants',
#  'Attends',
#  'Awake',
#  'Away!',
#  'Away,',
#  'Ay',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'Ay,',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'BERNARDO',
#  'Baked',
#  'Baptista:',
#  'Barbary',
#  'Barbary',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Be',
#  'Bear',
#  "Bear't",
#  'Bears',
#  'Becomes',
#  'Been',
#  'Been',
#  'Before',
#  'Before',
#  'Before',
#  'Before',
#  'Beggar',
#  'Begin,',
#  'Behind',
#  'Behind',
#  'Being',
#  'Being',
#  'Being',
#  'Believe',
#  'Believe',
#  'Believe',
#  'Belike',
#  'Bernardo',
#  'Bernardo',
#  'Bernardo!',
#  'Bernardo,',
#  'Bernardo?',
#  'Besides,',
#  'Bestial',
#  'Bestow',
#  'Between',
#  'Between',
#  'Beware',
#  'Bid',
#  'Black',
#  'Blasted',
#  'Blasting',
#  'Both',
#  'Both',
#  'Both',
#  'Both',
#  'Bow,',
#  'Break',
#  'Break',
#  'Break',
#  'Breathing',
#  'Brief',
#  'Bring',
#  'Bring',
#  'Brutus',
#  'Burn',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'But,',
#  'Buys',
#  'Buz,',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  'By',
#  "By'r",
#  'CLAUDIUS',
#  'CLAUDIUS',
#  'CLAUDIUS',
#  'CLAUDIUS',
#  'CLAUDIUS',
#  'CLAUDIUS',
#  'CLAUDIUS',
#  ...]
